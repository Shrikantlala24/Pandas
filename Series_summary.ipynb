# %% [markdown]
# # Series Summary + problems(200) :-
#
# here we'll summarize the series data structure of pandas. so make sure you check it out.

# %%
import numpy as np
import pandas as pd

# %%
# first let's create a pandas Series
data = np.array(['a', 'b', 'c', 'd', 'e'])
series = pd.Series(data)
print("Pandas Series:")
print(series)
# Out:
# Pandas Series:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object

# %%
# how to flatten a series like this :-

# Original Series of list
# 0    [Red, Green, White]
# 1           [Red, Black]
# 2               [Yellow]

ser = pd.Series([['Red', 'Green', 'White'], ['Red', 'Black'], ['Yellow']])

ser
# Flattening the Series
flat = [el for arr in ser for el in arr]
flat_series = pd.Series(flat)
print("\nFlattened Series:")
print(flat_series)
# Out:
# Flattened Series:
# 0       Red
# 1     Green
# 2     White
# 3       Red
# 4     Black
# 5    Yellow
# dtype: object

# %%
# # sorting this series :-

# # Original Data Series:
# # 0       100
# # 1       200
# # 2    python
# # 3    300.12
# # 4       400

# # output :-
# # 0       100
# # 1       200
# # 3    300.12
# # 4       400
# # 2    python

# data = [100, 200,'PYTHON' , 300.12, 400]
# ser = pd.Series(data)
# # sorted_ser = ser.sort_values()
# print("\nSorted Series:")
# print(sorted_ser)
# Out:
# Sorted Series:
# 0    100.00
# 1    200.00
# 2    300.12
# 3    400.00
# dtype: float64
