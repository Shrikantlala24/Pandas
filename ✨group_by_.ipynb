# %%
import numpy as np
import pandas as pd

# %%
ipl = pd.read_csv(r"C:\Users\HP\Downloads\deliveries.csv")
movies = pd.read_csv(r"C:\Users\HP\Downloads\imdb-top-1000.csv")

# %%
movies.head()
# Out:
#                Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      142   Drama          9.3
# 1             The Godfather          1972      175   Crime          9.2
# 2           The Dark Knight          2008      152  Action          9.0
# 3    The Godfather: Part II          1974      202   Crime          9.0
# 4              12 Angry Men          1957       96   Crime          9.0
#
#                Director           Star1  No_of_Votes        Gross  Metascore
# 0        Frank Darabont     Tim Robbins      2343110   28341469.0       80.0
# 1  Francis Ford Coppola   Marlon Brando      1620367  134966411.0      100.0
# 2     Christopher Nolan  Christian Bale      2303232  534858444.0       84.0
# 3  Francis Ford Coppola       Al Pacino      1129952   57300000.0       90.0
# 4          Sidney Lumet     Henry Fonda       689845    4360000.0       96.0

# %%
genres = movies.groupby("Genre")
genres.apply(lambda x : x)
# genres
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20780\3265664615.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   genres.apply(lambda x : x)
#                                                    Series_Title Released_Year  \
# Genre
# Action   2                                      The Dark Knight          2008
#          5        The Lord of the Rings: The Return of the King          2003
#          8                                            Inception          2010
#          10   The Lord of the Rings: The Fellowship of the Ring          2001
#          13               The Lord of the Rings: The Two Towers          2002
# ...

# %%
# genres.size()
some = movies.Genre.groupby(movies['Released_Year']).apply(lambda x: x).value_counts()
# type(some)
some
# Out:
# Genre
# Drama        289
# Action       172
# Comedy       155
# Crime        107
# Biography     88
# Animation     82
# Adventure     72
# Mystery       12
# Horror        11
# Western        4
# Film-Noir      3
# Fantasy        2
# Family         2
# Thriller       1
# Name: count, dtype: int64

# %%
# let's use some methods on groupby object
genres.groups
# Out:
# {'Action': [2, 5, 8, 10, 13, 14, 16, 29, 30, 31, 39, 42, 44, 55, 57, 59, 60, 63, 68, 72, 106, 109, 129, 130, 134, 140, 142, 144, 152, 155, 160, 161, 166, 168, 171, 172, 177, 181, 194, 201, 202, 216, 217, 223, 224, 236, 241, 262, 275, 294, 308, 320, 325, 326, 331, 337, 339, 340, 343, 345, 348, 351, 353, 356, 357, 362, 368, 369, 375, 376, 390, 410, 431, 436, 473, 477, 479, 482, 488, 493, 496, 502, 507, 511, 532, 535, 540, 543, 564, 569, 570, 573, 577, 582, 583, 602, 605, 608, 615, 623, ...], 'Adventure': [21, 47, 93, 110, 114, 116, 118, 137, 178, 179, 191, 193, 209, 226, 231, 247, 267, 273, 281, 300, 301, 304, 306, 323, 329, 361, 366, 377, 402, 406, 415, 426, 458, 470, 497, 498, 506, 513, 514, 537, 549, 552, 553, 566, 576, 604, 609, 618, 638, 647, 675, 681, 686, 692, 711, 713, 739, 755, 781, 797, 798, 851, 873, 884, 912, 919, 947, 957, 964, 966, 984, 991], 'Animation': [23, 43, 46, 56, 58, 61, 66, 70, 101, 135, 146, 151, 158, 170, 197, 205, 211, 213, 219, 229, 230, 242, 245, 246, 270, 
# ...

# %%
genres.get_group('Action')
# Out:
#                                           Series_Title Released_Year  Runtime  \
# 2                                      The Dark Knight          2008      152
# 5        The Lord of the Rings: The Return of the King          2003      201
# 8                                            Inception          2010      148
# 10   The Lord of the Rings: The Fellowship of the Ring          2001      178
# 13               The Lord of the Rings: The Two Towers          2002      179
# ..                                                 ...           ...      ...
# 968                                       Falling Down          1993      113
# 979                                      Lethal Weapon          1987      109
# 982                                          Mad Max 2          1981       96
# 983                                       The Warriors          1979       92
# 985                               Escape from Alcatraz          1979      112
#
# ...

# %%
genres['IMDB_Rating'].agg(['mean', 'max', 'min'])
# Out:
#                mean  max  min
# Genre
# Action     7.949419  9.0  7.6
# Adventure  7.937500  8.6  7.6
# Animation  7.930488  8.6  7.6
# Biography  7.938636  8.9  7.6
# Comedy     7.901290  8.6  7.6
# Crime      8.016822  9.2  7.6
# Drama      7.957439  9.3  7.6
# Family     7.800000  7.8  7.8
# Fantasy    8.000000  8.1  7.9
# Film-Noir  7.966667  8.1  7.8
# Horror     7.909091  8.5  7.6
# Mystery    7.975000  8.4  7.6
# Thriller   7.800000  7.8  7.8
# Western    8.350000  8.8  7.8

# %%
genres.agg({'IMDB_Rating' : ['mean', 'max', 'min'], 'Released_Year' : ['first', 'last', 'nunique']})
# Out:
#           IMDB_Rating           Released_Year
#                  mean  max  min         first  last nunique
# Genre
# Action       7.949419  9.0  7.6          2008  1979      61
# Adventure    7.937500  8.6  7.6          2014  1970      49
# Animation    7.930488  8.6  7.6          2001  1967      35
# Biography    7.938636  8.9  7.6          1993  1978      44
# Comedy       7.901290  8.6  7.6          2019  1961      72
# Crime        8.016822  9.2  7.6          1972  1935      56
# Drama        7.957439  9.3  7.6          1994  1944      83
# Family       7.800000  7.8  7.8          1982  1971       2
# Fantasy      8.000000  8.1  7.9          1920  1922       2
# Film-Noir    7.966667  8.1  7.8          1949  1943       3
# Horror       7.909091  8.5  7.6          1960  2001      11
# Mystery      7.975000  8.4  7.6          2000  1997      11
# Thriller     7.800000  7.8  7.8          1967  1967       1
# Western      8.350000  8.8  7.8          1966  1976       4

# %%
genres.min()
# Out:
#                               Series_Title Released_Year  Runtime  \
# Genre
# Action                                 300          1924       45
# Adventure            2001: A Space Odyssey          1925       88
# Animation                            Akira          1940       71
# Biography                 12 Years a Slave          1928       93
# Comedy                (500) Days of Summer          1921       68
# Crime                         12 Angry Men          1931       80
# Drama                                 1917          1925       64
# Family          E.T. the Extra-Terrestrial          1971      100
# Fantasy       Das Cabinet des Dr. Caligari          1920       76
# Film-Noir                Shadow of a Doubt          1941      100
# Horror                               Alien          1933       71
# Mystery                          Dark City          1938       96
# Thriller                   Wait Until Dark          1967      108
# ...

# %%
genres['Gross'].sum().sort_values(ascending=False)
# Out:
# Genre
# Drama        3.540997e+10
# Action       3.263226e+10
# Comedy       1.566387e+10
# Animation    1.463147e+10
# Adventure    9.496922e+09
# Crime        8.452632e+09
# Biography    8.276358e+09
# Mystery      1.256417e+09
# Horror       1.034649e+09
# Fantasy      7.827267e+08
# Family       4.391106e+08
# Film-Noir    1.259105e+08
# Western      5.822151e+07
# Thriller     1.755074e+07
# Name: Gross, dtype: float64

# %%
# movies['Gross'].sum()
df = pd.read_csv(r"C:\Users\HP\Downloads\indian_cities_full_150.csv")
df.population.sum()  # 125635140
# Out:
# 125635140

# %%
print(df[df.city_tier == "Tier-1"].population.sum())
print(df[df.city_tier == "Tier-2"].population.sum())
print(df[df.city_tier == "Tier-3"].population.sum())
# 125635140
# Out:
# 66492550
# 43244700
# 15897890

# %%
df.groupby('city_tier').population.sum()  # 125635140
df_tiers = df.groupby('city_tier')

# %%
# df_tiers.agg([sum,min,max])
idx = df_tiers.population.idxmax()
df.iloc[idx]
# Out:
#    city_name city_tier  population
# 0     Mumbai    Tier-1    12442373
# 10   Lucknow    Tier-2     3382000
# 40    Mysuru    Tier-3      920550

# %%
genres.agg('mean', numeric_only=True)
genres.mean(numeric_only=True)
genres.agg(['mean', 'max', 'min', ], numeric_only=True)
# Out:
#                Runtime  IMDB_Rating   No_of_Votes         Gross   Metascore
# Genre
# Action      812.290222     0.092573  1.874429e+11  5.092802e+16  154.287501
# Adventure  1110.043818     0.052799  9.071442e+10  2.881653e+16  152.408730
# Animation   211.134598     0.064121  6.873480e+10  4.375794e+16   77.680360
# Biography   650.987983     0.071364  7.359511e+10  1.858452e+16  121.620902
# Comedy      526.528697     0.052336  3.559017e+10  3.788913e+16  139.929032
# Crime       766.693528     0.112545  1.398758e+11  2.468643e+16  171.586474
# Drama       769.534770     0.071411  9.336335e+10  4.845123e+16  162.427040
# Family      112.500000     0.000000  1.877128e+10  9.292815e+16  288.000000
# Fantasy     162.000000     0.020000  4.919130e+08  5.786433e+15         NaN
# Film-Noir    16.000000     0.023333  2.986522e+09  4.968096e+15    2.333333
# Horror      185.090909     0.096909  5.517026e+10  9.930155e+15  236.000000
# ...

# %%
movies.groupby([ 'Director', 'Star1']).Gross.sum().sort_values(ascending=False)
# Out:
# Director              Star1
# Akira Kurosawa        Toshirô Mifune     2.999877e+09
# Anthony Russo         Joe Russo          2.205039e+09
# Billy Wilder          William Holden     1.286779e+09
# Christopher Nolan     Christian Bale     1.242940e+09
# Werner Herzog         Klaus Kinski       1.124605e+09
#                                              ...
# Jeong-beom Lee        Won Bin            6.460000e+03
# Shane Meadows         Paddy Considine    6.013000e+03
# Jaco Van Dormael      Jared Leto         3.600000e+03
# Thomas Jahn           Til Schweiger      3.296000e+03
# Anders Thomas Jensen  Ulrich Thomsen     1.305000e+03
# Name: Gross, Length: 898, dtype: float64

# %%
movies.head()
# Out:
#                Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      142   Drama          9.3
# 1             The Godfather          1972      175   Crime          9.2
# 2           The Dark Knight          2008      152  Action          9.0
# 3    The Godfather: Part II          1974      202   Crime          9.0
# 4              12 Angry Men          1957       96   Crime          9.0
#
#                Director           Star1  No_of_Votes        Gross  Metascore
# 0        Frank Darabont     Tim Robbins      2343110   28341469.0       80.0
# 1  Francis Ford Coppola   Marlon Brando      1620367  134966411.0      100.0
# 2     Christopher Nolan  Christian Bale      2303232  534858444.0       84.0
# 3  Francis Ford Coppola       Al Pacino      1129952   57300000.0       90.0
# 4          Sidney Lumet     Henry Fonda       689845    4360000.0       96.0

# %%
# help(pd.DataFrame.groupby)
genres.groups
genres.get_group('Action')
# Out:
#                                           Series_Title Released_Year  Runtime  \
# 2                                      The Dark Knight          2008      152
# 5        The Lord of the Rings: The Return of the King          2003      201
# 8                                            Inception          2010      148
# 10   The Lord of the Rings: The Fellowship of the Ring          2001      178
# 13               The Lord of the Rings: The Two Towers          2002      179
# ..                                                 ...           ...      ...
# 968                                       Falling Down          1993      113
# 979                                      Lethal Weapon          1987      109
# 982                                          Mad Max 2          1981       96
# 983                                       The Warriors          1979       92
# 985                               Escape from Alcatraz          1979      112
#
# ...

# %%
genres.describe()
# Out:
#           Runtime                                                              \
#             count        mean        std    min     25%    50%     75%    max
# Genre
# Action      172.0  129.046512  28.500706   45.0  110.75  127.5  143.25  321.0
# Adventure    72.0  134.111111  33.317320   88.0  109.00  127.0  149.00  228.0
# Animation    82.0   99.585366  14.530471   71.0   90.00   99.5  106.75  137.0
# Biography    88.0  136.022727  25.514466   93.0  120.00  129.0  146.25  209.0
# Comedy      155.0  112.129032  22.946213   68.0   96.00  106.0  124.50  188.0
# Crime       107.0  126.392523  27.689231   80.0  106.50  122.0  141.50  229.0
# Drama       289.0  124.737024  27.740490   64.0  105.00  121.0  137.00  242.0
# Family        2.0  107.500000  10.606602  100.0  103.75  107.5  111.25  115.0
# Fantasy       2.0   85.000000  12.727922   76.0   80.50   85.0   89.50   94.0
# Film-Noir     3.0  104.000000   4.000000  100.0  102.00  104.0  106.00  108.0
# ...

# %%
genres.nunique()
# Out:
#            Series_Title  Released_Year  Runtime  IMDB_Rating  Director  Star1  \
# Genre
# Action              172             61       78           15       123    121
# Adventure            72             49       58           10        59     59
# Animation            82             35       41           11        51     77
# Biography            88             44       56           13        76     72
# Comedy              155             72       70           11       113    133
# Crime               106             56       65           14        86     85
# Drama               289             83       95           14       211    250
# Family                2              2        2            1         2      2
# Fantasy               2              2        2            2         2      2
# Film-Noir             3              3        3            3         3      3
# Horror               11             11       10            8        10     11
# ...

# %%
genres.Runtime.describe()
# Out:
#            count        mean        std    min     25%    50%     75%    max
# Genre
# Action     172.0  129.046512  28.500706   45.0  110.75  127.5  143.25  321.0
# Adventure   72.0  134.111111  33.317320   88.0  109.00  127.0  149.00  228.0
# Animation   82.0   99.585366  14.530471   71.0   90.00   99.5  106.75  137.0
# Biography   88.0  136.022727  25.514466   93.0  120.00  129.0  146.25  209.0
# Comedy     155.0  112.129032  22.946213   68.0   96.00  106.0  124.50  188.0
# Crime      107.0  126.392523  27.689231   80.0  106.50  122.0  141.50  229.0
# Drama      289.0  124.737024  27.740490   64.0  105.00  121.0  137.00  242.0
# Family       2.0  107.500000  10.606602  100.0  103.75  107.5  111.25  115.0
# Fantasy      2.0   85.000000  12.727922   76.0   80.50   85.0   89.50   94.0
# Film-Noir    3.0  104.000000   4.000000  100.0  102.00  104.0  106.00  108.0
# Horror      11.0  102.090909  13.604812   71.0   98.00  103.0  109.00  122.0
# ...

# %%
genres.sample(2, replace=True )
# Out:
#                             Series_Title Released_Year  Runtime      Genre  \
# 351                              Yip Man          2008      106     Action
# 850                     Enter the Dragon          1973      102     Action
# 692            The Man Who Would Be King          1975      129  Adventure
# 323                                 Togo          2019      113  Adventure
# 229                         Mary and Max          2009       92  Animation
# 596                          Toy Story 4          2019      100  Animation
# 346                    The King's Speech          2010      118  Biography
# 139                   Bhaag Milkha Bhaag          2013      186  Biography
# 973                           Home Alone          1990      103     Comedy
# 565                 A Night at the Opera          1935       96     Comedy
# 163                               Eskiya          1996      128      Crime
# ...

# %%
genres.agg({'Runtime' :'mean', 'IMDB_Rating' : 'mean', 'No_of_Votes' : 'sum', 'Gross':'sum','Metascore':'mean'})
# Out:
#               Runtime  IMDB_Rating  No_of_Votes         Gross  Metascore
# Genre
# Action     129.046512     7.949419     72282412  3.263226e+10  73.419580
# Adventure  134.111111     7.937500     22576163  9.496922e+09  78.437500
# Animation   99.585366     7.930488     21978630  1.463147e+10  81.093333
# Biography  136.022727     7.938636     24006844  8.276358e+09  76.240506
# Comedy     112.129032     7.901290     27620327  1.566387e+10  78.720000
# Crime      126.392523     8.016822     33533615  8.452632e+09  77.080460
# Drama      124.737024     7.957439     61367304  3.540997e+10  79.701245
# Family     107.500000     7.800000       551221  4.391106e+08  79.000000
# Fantasy     85.000000     8.000000       146222  7.827267e+08        NaN
# Film-Noir  104.000000     7.966667       367215  1.259105e+08  95.666667
# Horror     102.090909     7.909091      3742556  1.034649e+09  80.000000
# Mystery    119.083333     7.975000      4203004  1.256417e+09  79.125000
# ...

# %%
idx = []

for grp,data in genres:
    # print(data['Runtime'].sum() / data.count())
    idx.append(data['IMDB_Rating'].idxmax())

movies.iloc[idx]
# Out:
#                         Series_Title Released_Year  Runtime      Genre  \
# 2                    The Dark Knight          2008      152     Action
# 21                      Interstellar          2014      169  Adventure
# 23     Sen to Chihiro no kamikakushi          2001      125  Animation
# 7                   Schindler's List          1993      195  Biography
# 19                      Gisaengchung          2019      132     Comedy
# 1                      The Godfather          1972      175      Crime
# 0           The Shawshank Redemption          1994      142      Drama
# 688       E.T. the Extra-Terrestrial          1982      115     Family
# 321     Das Cabinet des Dr. Caligari          1920       76    Fantasy
# 309                    The Third Man          1949      104  Film-Noir
# 49                            Psycho          1960      109     Horror
# 69                           Memento          2000      113    Mystery
# ...

# %%
# framo = pd.DataFrame()

def ranking(data):
    data['IMDB_rank'] = data['IMDB_Rating'].rank(ascending=False)
    return data.sort_values('IMDB_Rating',ascending=False)

framo = genres.apply(ranking)
framo.loc['Action']
# framo
# genres.count()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20780\684767915.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   framo = genres.apply(ranking)
#                                           Series_Title Released_Year  Runtime  \
# 2                                      The Dark Knight          2008      152
# 5        The Lord of the Rings: The Return of the King          2003      201
# 8                                            Inception          2010      148
# 10   The Lord of the Rings: The Fellowship of the Ring          2001      178
# 13               The Lord of the Rings: The Two Towers          2002      179
# ...

# %%
movies['IMDB_Rating'].sort_values(ascending=False)
# Out:
# 0      9.3
# 1      9.2
# 2      9.0
# 3      9.0
# 4      9.0
#       ...
# 912    7.6
# 911    7.6
# 910    7.6
# 909    7.6
# 999    7.6
# Name: IMDB_Rating, Length: 1000, dtype: float64

# %%
idx = genres['IMDB_Rating'].idxmax()
movies.loc[idx]
# movies[movies['Genre'] == 'Adventure'].sort_values('Series_Title', ascending=False).max()
# movies.iloc[i]
# Out:
#                         Series_Title Released_Year  Runtime      Genre  \
# 2                    The Dark Knight          2008      152     Action
# 21                      Interstellar          2014      169  Adventure
# 23     Sen to Chihiro no kamikakushi          2001      125  Animation
# 7                   Schindler's List          1993      195  Biography
# 19                      Gisaengchung          2019      132     Comedy
# 1                      The Godfather          1972      175      Crime
# 0           The Shawshank Redemption          1994      142      Drama
# 688       E.T. the Extra-Terrestrial          1982      115     Family
# 321     Das Cabinet des Dr. Caligari          1920       76    Fantasy
# 309                    The Third Man          1949      104  Film-Noir
# 49                            Psycho          1960      109     Horror
# 69                           Memento          2000      113    Mystery
# ...

# %%
movies.groupby('Star1')['Series_Title'].count().sort_values(ascending=False)
# Out:
# Star1
# Tom Hanks             12
# Robert De Niro        11
# Clint Eastwood        10
# Al Pacino             10
# Leonardo DiCaprio      9
#                       ..
# Glen Hansard           1
# Giuseppe Battiston     1
# Giulietta Masina       1
# Gerardo Taracena       1
# Ömer Faruk Sorak       1
# Name: Series_Title, Length: 660, dtype: int64

# %%
def start_A(grp) :
    mask = grp['Series_Title'].str.startswith('A')
    return grp[mask]


genres.apply(start_A)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20780\3818469201.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   genres.apply(start_A)
#                       Series_Title Released_Year  Runtime   Genre  \
# Genre
# Action 59        Avengers: Endgame          2019      181  Action
#        60   Avengers: Infinity War          2018      149  Action
#        106                  Aliens          1986      137  Action
#        166         Andaz Apna Apna          1994      160  Action
#        224             A Wednesday          2008      104  Action
# ...                            ...           ...      ...     ...
# Drama  804           Abre los ojos          1997      119   Drama
# ...

# %%
def rank_laga(grp):
    grp['Imdb rank'] = grp['IMDB_Rating'].rank(ascending=False)
    return grp.sort_values('IMDB_Rating', ascending=False)

# genres.apply(lambda x: x)
genres.apply(rank_laga)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20780\2487055141.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   genres.apply(rank_laga)
#                                                    Series_Title Released_Year  \
# Genre
# Action   2                                      The Dark Knight          2008
#          5        The Lord of the Rings: The Return of the King          2003
#          8                                            Inception          2010
#          10   The Lord of the Rings: The Fellowship of the Ring          2001
#          13               The Lord of the Rings: The Two Towers          2002
# ...

# %%
temp = ipl[ipl['over'] >15]
mask_in_temp = temp['batsman_runs'].isin([4,6])


# temp[mask_in_temp]['batsman'].value_counts()

temp[mask_in_temp]['batsman'].groupby(temp['batsman']).count().sort_values(ascending=False)
# Out:
# batsman
# MS Dhoni          340
# AB de Villiers    208
# RG Sharma         208
# KA Pollard        206
# V Kohli           160
#                  ...
# KC Cariappa         1
# Shivam Sharma       1
# Shoaib Malik        1
# T Curran            1
# KJ Abbott           1
# Name: batsman, Length: 360, dtype: int64
