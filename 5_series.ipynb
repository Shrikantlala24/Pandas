# %% [markdown]
# # Series Cretion and operations
# Seires always contains two things - Index (Unique ID) and data (values). both of them can be either integers or objects (i.e. strings), the only restriction is the Index should be uniques
