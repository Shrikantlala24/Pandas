# %% [markdown]
# # Killer functions
# here we'll learn some of the best methods/functions that we'll be using most of the times, whenever we are working on data
#
# 1. value_count()
# 2. sort_values()
# 3. drop_duplicates()
# 4. groupby()
#
# ### 1. Value_count()
# we use it to count no. of frequencies of categories in categorical columns
