# %% [markdown]
# # Pandas - the beginning
# it is a software library used for data manipulation and analysis in python language. it offers data structures and the operations which are used to manipulate and operate on data frames and time series.
#
# thier are mainly two forms of data structures, we majorly use in pandas :-
#
#     1. Data frames
#     2. series
