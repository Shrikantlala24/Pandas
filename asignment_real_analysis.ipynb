# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
marks = pd.read_csv(r"c:\Users\HP\Downloads\Book1.csv")

# %%
marks
# Out:
#      Sr No.                 Full Name  Roll No.  \
# 0         1          Aakanksha Ranjan  23AM1090
# 1         2               Aarin Khare  23AM1135
# 2         3    Aarnav Ageya Bharadwaj  23CE1267
# 3         4              Aaryan Nanda  23CE1145
# 4         5              Aaryan Singh  24CC5005
# ..      ...                       ...       ...
# 345     346   Yash Niteshkumar Pathak  23AM1064
# 346     347      Yash Rajesh Deshmukh  23CE1143
# 347     348      Yashvi Amith Poojari  23CB1016
# 348     349  Yazad Firdosh Pooniwalla  23AD1027
# 349     350    Yugeshwar Hemant Singh  23AM1154
#
#                                            Branch                 College ID  \
# 0    Artificial Intelligence and Machine Learning   aak.ran.rt23@dypatil.edu
# 1    Artificial Intelligence and Machine Learning   aar.kha.rt23@dypatil.edu
# 2                            Computer Engineering   aar.bha.rt23@dypatil.edu
# ...

# %%
# marks.Branch.value_counts()
marks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sr No.          350 non-null    int64
#  1   Full Name       350 non-null    object
#  2   Roll No.        350 non-null    object
#  3   Branch          350 non-null    object
#  4   College ID      347 non-null    object
#  5   Total Marks 30  350 non-null    object
#  6   Percentage      350 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 19.3+ KB

# %%
def rem_perc(col) :
    return col.replace("%","")

# %%
marks.Percentage = marks.Percentage.apply(rem_perc)
marks
# Out:
#      Sr No.                 Full Name  Roll No.  \
# 0         1          Aakanksha Ranjan  23AM1090
# 1         2               Aarin Khare  23AM1135
# 2         3    Aarnav Ageya Bharadwaj  23CE1267
# 3         4              Aaryan Nanda  23CE1145
# 4         5              Aaryan Singh  24CC5005
# ..      ...                       ...       ...
# 345     346   Yash Niteshkumar Pathak  23AM1064
# 346     347      Yash Rajesh Deshmukh  23CE1143
# 347     348      Yashvi Amith Poojari  23CB1016
# 348     349  Yazad Firdosh Pooniwalla  23AD1027
# 349     350    Yugeshwar Hemant Singh  23AM1154
#
#                                            Branch                 College ID  \
# 0    Artificial Intelligence and Machine Learning   aak.ran.rt23@dypatil.edu
# 1    Artificial Intelligence and Machine Learning   aar.kha.rt23@dypatil.edu
# 2                            Computer Engineering   aar.bha.rt23@dypatil.edu
# ...

# %%
marks.Percentage = marks.Percentage.astype(np.int32)

# marks.info()

# marks.groupby("Branch")["Percentage"].sort_values(ascending=False)
marks.value_counts('Percentage')
# Out:
# Percentage
# 0     246
# 17     82
# 33     16
# 50      3
# 67      3
# Name: count, dtype: int64

# %%
marks.value_counts('Percentage').plot(kind='pie')
# Out:
# <Axes: ylabel='count'>
