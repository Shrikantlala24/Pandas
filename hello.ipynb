# %%
import numpy as np
import pandas as pd

# %%
myindex = ['maths','chemistry','physics']
mydata = [100,98,97]

marks = pd.Series(data=mydata, index=myindex)
marks.values
# Out:
# array([100,  98,  97], dtype=int64)

# %%
pd.Series({'A':10,'B':20,'C':30})
# Out:
# A    10
# B    20
# C    30
# dtype: int64

# %%
subs = (pd.read_csv('C:\\Users\\HP\\Downloads\\subs.csv')).squeeze()
# help(pd.read_csv)
# (subs.values)
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
Kohli = pd.read_csv(r'C:\Users\HP\Downloads\kohli_ipl.csv', index_col='match_no')
Kohli = Kohli.squeeze()
# Kohli[-1]
# subs[-1]

# %%
movies = pd.read_csv(r'C:\Users\HP\Downloads\bollywood.csv', index_col='movie').squeeze()
movies.tail()
# Out:
# movie
# Hum Tumhare Hain Sanam      Shah Rukh Khan
# Aankhen (2002 film)       Amitabh Bachchan
# Saathiya (film)               Vivek Oberoi
# Company (film)                  Ajay Devgn
# Awara Paagal Deewana          Akshay Kumar
# Name: lead, dtype: object

# %%
Kohli[::3]
print(type(Kohli.values))
print(type(pd.Series(sorted(subs))))
print(type(marks.index))
print(type(movies.index))
sorted(subs)
# Out:
# <class 'numpy.ndarray'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.indexes.base.Index'>
# <class 'pandas.core.indexes.base.Index'>
# [33,
#  33,
#  35,
#  37,
#  39,
#  40,
#  40,
#  40,
#  40,
#  42,
#  42,
#  43,
#  44,
#  44,
#  44,
#  45,
#  46,
#  46,
#  48,
#  49,
#  49,
#  49,
#  49,
#  50,
#  50,
#  50,
#  51,
#  54,
#  56,
#  56,
#  56,
#  56,
#  57,
#  61,
#  62,
#  64,
#  65,
#  65,
#  66,
#  66,
#  66,
#  66,
#  67,
#  68,
#  70,
#  70,
#  70,
#  71,
#  71,
#  72,
#  72,
#  72,
#  72,
#  72,
#  73,
#  74,
#  74,
#  75,
#  76,
#  76,
#  76,
#  76,
#  77,
#  77,
#  78,
#  78,
#  78,
#  79,
#  79,
#  80,
#  80,
#  80,
#  81,
#  81,
#  82,
#  82,
#  83,
#  83,
#  83,
#  84,
#  84,
#  84,
#  85,
#  86,
#  86,
#  86,
#  87,
#  87,
#  87,
#  87,
#  88,
#  88,
#  88,
#  88,
#  88,
#  89,
#  89,
#  89,
#  90,
#  90,
#  90,
#  90,
#  91,
#  92,
#  92,
#  92,
#  93,
#  93,
#  93,
#  93,
#  95,
#  95,
#  96,
#  96,
#  96,
#  96,
#  97,
#  97,
#  98,
#  98,
#  99,
# ...

# %%
marks
(97) in marks.values
# Out:
# True

# %%
# movies mein kitne actors hain jinhone 20 se zyada movies ki hain
actors = movies.value_counts()
actors[actors>20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %%
Inte = pd.Series([10.0,100.0,25.0])
marks
# Out:
# maths        100
# chemistry     98
# physics       97
# dtype: int64

# %%
Kohli.astype('int16').info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 215 entries, 1 to 215
# Series name: runs
# Non-Null Count  Dtype
# --------------  -----
# 215 non-null    int16
# dtypes: int16(1)
# memory usage: 2.1 KB

# %%
subs.between(50,100)
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 360    False
# 361    False
# 362    False
# 363    False
# 364    False
# Name: Subscribers gained, Length: 365, dtype: bool

# %%
subs.clip(50,100).sort_values()
# Out:
# 0       50
# 31      50
# 29      50
# 26      50
# 25      50
#       ...
# 204    100
# 205    100
# 206    100
# 208    100
# 364    100
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
movies.unique()
# Out:
# array(['Vicky Kaushal', 'Vicky Ahuja', 'Anupam Kher', 'Emraan Hashmi',
#        'Mona Ambegaonkar', 'Geetika Vidya Ohlyan', 'Arshad Warsi',
#        'Radhika Apte', 'Kangana Ranaut', 'Nawazuddin Siddiqui',
#        'Ali Asgar', 'Ranveer Singh', 'Prit Kamani', 'Ajay Devgn',
#        'Sushant Singh Rajput', 'Amitabh Bachchan', 'Abhimanyu Dasani',
#        'Talha Arshad Reshi', 'Garima Agarwal', 'Rasika Agashe',
#        'Barun Sobti', 'Akshay Kumar', 'Zaheer Iqbal', 'Vidyut Jammwal',
#        'Deepika Amin', 'Manav Kaul', 'Naseeruddin Shah', 'Varun Dhawan',
#        'Shreyas Talpade', 'Tiger Shroff', 'Boman Irani', 'Arjun Kapoor',
#        'Gavie Chahal', 'Prabhu Deva', 'Shahid Kapoor',
#        'Ayushmann Khurrana', 'Karanvir Bohra', 'Hrithik Roshan',
#        'Jimmy Sheirgill', 'John Abraham', 'Rishi Kapoor',
#        'Natalia Janoszek', 'Diljit Dosanjh', 'Sidharth Malhotra',
#        'Rajeev Khandelwal', 'Zaira Wasim', 'Jacqueline Fernandez',
# ...
